# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#      |████████████████████████████████| 111 kB 2.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 79 kB 1.8 MB/s eta 0:00:01
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=b2f6a1c274a0844264fe84c7b1748679b4428a13cb294854be4a84433f35f19a
#   Stored in directory: /Users/jayleonard/Library/Caches/pip/wheels/ef/4c/4a/17fd3d7fb7b6243d5a7a8d165870cd5c6ad2ec4c0582f039e4
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.11.0
#     Uninstalling folium-0.11.0:
#       Successfully uninstalled folium-0.11.0
# ...
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'D15ONHG44F1ZJ1MXNDY4PL5REE35O2SUNZ1S2DU5IBR1QWMB' # your Foursquare ID
CLIENT_SECRET = '0X1HRVHKU51Q4UKKCOX5BX3CBZ2M2CG5M3HYSOPVXXURK4DI' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: D15ONHG44F1ZJ1MXNDY4PL5REE35O2SUNZ1S2DU5IBR1QWMB
# CLIENT_SECRET:0X1HRVHKU51Q4UKKCOX5BX3CBZ2M2CG5M3HYSOPVXXURK4DI

# %%
address = '1636 N Cleveland Ave, Chicago, IL'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.91212745 -87.64125096929477

# %%
search_query = 'Gym'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Gym .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=D15ONHG44F1ZJ1MXNDY4PL5REE35O2SUNZ1S2DU5IBR1QWMB&client_secret=0X1HRVHKU51Q4UKKCOX5BX3CBZ2M2CG5M3HYSOPVXXURK4DI&ll=41.91212745,-87.64125096929477&v=20180604&query=Gym&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f8dbb59b530f203325acf0c'},
#  'response': {'venues': [{'id': '4e9cc2ce82310f9e5f41a2df',
#     'name': 'Ren North Gym',
#     'location': {'lat': 41.911105,
#      'lng': -87.642995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.911105,
#        'lng': -87.642995}],
#      'distance': 183,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603124057',
#     'hasPerk': False},
#    {'id': '5664829e498e05209309b953',
#     'name': 'City Livin - Gym',
#     'location': {'lat': 41.913034,
#      'lng': -87.637262,
# ...

# %%
gyms = results["response"]["venues"]
gyms
# Out:
# [{'id': '4e9cc2ce82310f9e5f41a2df',
#   'name': 'Ren North Gym',
#   'location': {'lat': 41.911105,
#    'lng': -87.642995,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 41.911105,
#      'lng': -87.642995}],
#    'distance': 183,
#    'cc': 'US',
#    'city': 'Chicago',
#    'state': 'IL',
#    'country': 'United States',
#    'formattedAddress': ['Chicago, IL', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1603124057',
#   'hasPerk': False},
#  {'id': '5664829e498e05209309b953',
#   'name': 'City Livin - Gym',
#   'location': {'lat': 41.913034,
#    'lng': -87.637262,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 41.913034,
#      'lng': -87.637262}],
#    'distance': 345,
#    'cc': 'US',
# ...

# %%
df = json_normalize(gyms)
df.head()
# Out:
# <ipython-input-26-58fc644abd60>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = json_normalize(gyms)
#                          id                     name  \
# 0  4e9cc2ce82310f9e5f41a2df            Ren North Gym
# 1  5664829e498e05209309b953         City Livin - Gym
# 2  51fbe53c498ea3afd8cb5379  Gym at Americana Towers
# 3  52b13089498efd2def262e6e                 1660 Gym
# 4  506cdbace4b0dbcc80bd3cf5             Kennelly Gym
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1603124057    False
# 1  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1603124057    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1603124057    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1603124057    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1603124057    False
#
# ...

# %%
df.shape
# Out:
# (11, 17)

# %%
df
# Out:
#                           id                     name  \
# 0   4e9cc2ce82310f9e5f41a2df            Ren North Gym
# 1   5664829e498e05209309b953         City Livin - Gym
# 2   51fbe53c498ea3afd8cb5379  Gym at Americana Towers
# 3   52b13089498efd2def262e6e                 1660 Gym
# 4   506cdbace4b0dbcc80bd3cf5             Kennelly Gym
# 5   4e1e27957d8bc15ae53842d1                 LC's Gym
# 6   4ddc6f27d22df17198ffa060            Americana Gym
# 7   4fc02c7be4b0a6eab91df804          Spartan 300 Gym
# 8   57af0bc1498ee20e7533a535      Eugenie Terrace Gym
# 9   4aa6f880f964a520ab4b20e3     Equinox Lincoln Park
# 10  4bb505f30ef1c9b6cec4f412   JMac's 1660 N. LaSalle
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1603124057    False
# 1   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1603124057    False
# 2   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1603124057    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
dataframe_filtered = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                        name                                categories  \
# 0             Ren North Gym                                       Gym
# 1          City Livin - Gym  Residential Building (Apartment / Condo)
# 2   Gym at Americana Towers                                       Gym
# 3                  1660 Gym                      Gym / Fitness Center
# 4              Kennelly Gym                                       Gym
# 5                  LC's Gym                      Gym / Fitness Center
# 6             Americana Gym                                       Gym
# 7           Spartan 300 Gym                                       Gym
# 8       Eugenie Terrace Gym                               College Gym
# 9      Equinox Lincoln Park                                       Gym
# 10   JMac's 1660 N. LaSalle                                       Gym
#
#           lat        lng                                     labeledLatLngs  \
# ...

# %%
df.name
# Out:
# 0               Ren North Gym
# 1            City Livin - Gym
# 2     Gym at Americana Towers
# 3                    1660 Gym
# 4                Kennelly Gym
# 5                    LC's Gym
# 6               Americana Gym
# 7             Spartan 300 Gym
# 8         Eugenie Terrace Gym
# 9        Equinox Lincoln Park
# 10     JMac's 1660 N. LaSalle
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add a red circle marker to represent the spot 
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gym_id = df[df["name"] == "1660 Gym"]["id"]
gym_id
# Out:
# 3    52b13089498efd2def262e6e
# Name: id, dtype: object

# %%
venue_id = "52b13089498efd2def262e6e" # ID of close gym
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/52b13089498efd2def262e6e?client_id=D15ONHG44F1ZJ1MXNDY4PL5REE35O2SUNZ1S2DU5IBR1QWMB&client_secret=0X1HRVHKU51Q4UKKCOX5BX3CBZ2M2CG5M3HYSOPVXXURK4DI&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '52b13089498efd2def262e6e',
#  'name': '1660 Gym',
#  'contact': {},
#  'location': {'address': '1660 N La Salle Dr',
#   'lat': 41.91281010561471,
#   'lng': -87.63371932930417,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 41.91281010561471,
#     'lng': -87.63371932930417}],
#   'postalCode': '60614',
#   'cc': 'US',
#   'city': 'Chicago',
#   'state': 'IL',
#   'country': 'United States',
#   'formattedAddress': ['1660 N La Salle Dr',
#    'Chicago, IL 60614',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/1660-gym/52b13089498efd2def262e6e',
#  'categories': [{'id': '4bf58dd8d48988d175941735',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
gym_id2 = df[df["name"] == "Equinox Lincoln Park"]["id"]
gym_id2
# Out:
# 9    4aa6f880f964a520ab4b20e3
# Name: id, dtype: object

# %%
venue_id = '4aa6f880f964a520ab4b20e3' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.6

# %%
# This is a good rating!!!
